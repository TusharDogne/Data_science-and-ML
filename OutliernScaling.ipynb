# %%
import pandas as pd

# %%
data1 = pd.read_excel('/content/admission_dataset_100_rows.xlsx')
data1
# Out:
#     Exam1  Exam2  Admission
# 0      34     78          0
# 1      52     55          0
# 2      67     89          1
# 3      95     85          1
# 4      49     65          0
# ..    ...    ...        ...
# 95     78     84          1
# 96     69     68          0
# 97     88     92          1
# 98     91     90          1
# 99     64     69          1
#
# [100 rows x 3 columns]

# %%
data1.describe()
# Out:
#             Exam1       Exam2   Admission
# count  100.000000  100.000000  100.000000
# mean    65.730000   68.250000    0.600000
# std     18.182495   16.416532    0.492366
# min     31.000000   38.000000    0.000000
# 25%     52.750000   55.000000    0.000000
# 50%     65.500000   67.000000    1.000000
# 75%     80.250000   82.250000    1.000000
# max     99.000000   99.000000    1.000000

# %%
X = data1[['Exam1', 'Exam2']]
Y = data1['Admission']

# %%
std1 = data1['Exam1'].std()
std2 = data1['Exam2'].std()
print(std1)
print(std2)
# Out:
# 18.18249518941587
# 16.41653207143717

# %%
data1.dtypes
# Out:
# Exam1        int64
# Exam2        int64
# Admission    int64
# dtype: object

# %%
covarience = data1[['Exam1', 'Exam2', 'Admission']].cov()['Admission']

# %%
correlation = data1[['Exam1', 'Exam2', 'Admission']].corr()['Admission']

# %%
print(covarience)
print(correlation)
# Out:
# Exam1        7.082828
# Exam2        5.949495
# Admission    0.242424
# Name: Admission, dtype: float64
# Exam1        0.791162
# Exam2        0.736056
# Admission    1.000000
# Name: Admission, dtype: float64

# %%
covv = data1.cov()
print(covv)
# Out:
#                 Exam1       Exam2  Admission
# Exam1      330.603131  264.815657   7.082828
# Exam2      264.815657  269.502525   5.949495
# Admission    7.082828    5.949495   0.242424

# %%
corr = data1.corr()
print(corr)
# Out:
#               Exam1     Exam2  Admission
# Exam1      1.000000  0.887174   0.791162
# Exam2      0.887174  1.000000   0.736056
# Admission  0.791162  0.736056   1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(data1.corr(),annot=True)
plt.show()

# %%
data2 = pd.read_csv("/content/Heart_attack.csv")
data2
# Out:
#         HeartDiseaseorAttack  HighBP  HighChol  CholCheck   BMI  Smoker  \
# 0                          0       1         1          1  40.0       1
# 1                          0       0         0          0  25.0       1
# 2                          0       1         1          1  28.0       0
# 3                          0       1         0          1  27.0       0
# 4                          0       1         1          1  24.0       0
# ...                      ...     ...       ...        ...   ...     ...
# 129993                     0       1         1          1  25.0       1
# 129994                     0       0         0          1  27.0       0
# 129995                     0       0         0          1  29.0       0
# 129996                     0       0         0          0  21.0       0
# 129997                     0       0         0          1  21.0       1
#
#         Stroke  Diabetes  PhysActivity  HvyAlcoholConsump  MentHlth  PhysHlth  \
# ...

# %%
data2.describe()
# Out:
#        HeartDiseaseorAttack         HighBP       HighChol      CholCheck  \
# count         129998.000000  129998.000000  129998.000000  129998.000000
# mean               0.093509       0.429614       0.426322       0.963315
# std                0.291146       0.495023       0.494544       0.187988
# min                0.000000       0.000000       0.000000       0.000000
# 25%                0.000000       0.000000       0.000000       1.000000
# 50%                0.000000       0.000000       0.000000       1.000000
# 75%                0.000000       1.000000       1.000000       1.000000
# max                1.000000       1.000000       1.000000       1.000000
#
#                  BMI         Smoker         Stroke       Diabetes  \
# count  129988.000000  129998.000000  129998.000000  129998.000000
# mean       28.435586       0.448030       0.041354       0.296689
# std         6.999582       0.497294       0.199110       0.697608
# ...

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=data2['BMI'])
plt.title('Boxplot of BMI')
plt.ylabel('BMI')
plt.show()

# %%
data2.boxplot(figsize=(20,8))
plt.show()

# %%
"""Q1 = data2[''].quantile(0.25)
Q3 = data2['BMI'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Q1: ", Q1 )
print("Q3: ",Q3)
print("IQR: ",IQR)
print("Lower Bound:", lower_bound)
print("Upper Bound:" ,upper_bound)

outliers_bmi = data2[(data2['BMI'] < lower_bound) | (data2['BMI'] > upper_bound)]
print(f"Number of outliers in BMI: {len(outliers_bmi)}")
data2_cleaned = data2[(data2['BMI'] >= lower_bound) & (data2['BMI'] <= upper_bound)]

print("Original data2 shape: ", data2.shape)
print("Cleaned data2 shape: ", data2_cleaned.shape)"""
# Out:
# 'Q1 = data2[\'\'].quantile(0.25)\nQ3 = data2[\'BMI\'].quantile(0.75)\nIQR = Q3 - Q1\n\nlower_bound = Q1 - 1.5 * IQR\nupper_bound = Q3 + 1.5 * IQR\n\nprint("Q1: ", Q1 )\nprint("Q3: ",Q3)\nprint("IQR: ",IQR)\nprint("Lower Bound:", lower_bound)\nprint("Upper Bound:" ,upper_bound)\n\noutliers_bmi = data2[(data2[\'BMI\'] < lower_bound) | (data2[\'BMI\'] > upper_bound)]\nprint(f"Number of outliers in BMI: {len(outliers_bmi)}")\ndata2_cleaned = data2[(data2[\'BMI\'] >= lower_bound) & (data2[\'BMI\'] <= upper_bound)]\n\nprint("Original data2 shape: ", data2.shape)\nprint("Cleaned data2 shape: ", data2_cleaned.shape)'

# %%
x = data2['HeartDiseaseorAttack']
unique_values = x.unique()
print("Unique values in 'HeartDiseaseorAttack':", unique_values)
print("\nValue counts:")
print(x.value_counts())
# Out:
# Unique values in 'HeartDiseaseorAttack': [0 1]
#
# Value counts:
# HeartDiseaseorAttack
# 0    117842
# 1     12156
# Name: count, dtype: int64

# %%
Q1 = data2.quantile(0.25)
Q3 = data2.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("Q1: ", Q1 )
print("Q3: ",Q3)
print("IQR: ",IQR)
print("Lower Bound:", lower_bound)
print("Upper Bound:" ,upper_bound)
mask_within_bounds = (data2 >= lower_bound) & (data2 <= upper_bound)
data2_clean = data2[mask_within_bounds.all(axis=1)].copy()

print(f"\nOriginal data2 shape: {data2.shape}")
print(f"Cleaned data2 shape (after removing outliers from all columns): {data2_clean.shape}")
display(data2_clean.head())
# Out:
# Q1:  HeartDiseaseorAttack     0.0
# HighBP                   0.0
# HighChol                 0.0
# CholCheck                1.0
# BMI                     24.0
# Smoker                   0.0
# Stroke                   0.0
# Diabetes                 0.0
# PhysActivity             1.0
# HvyAlcoholConsump        0.0
# MentHlth                 0.0
# PhysHlth                 0.0
# Sex                      0.0
# Age                      6.0
# Education                4.0
# Income                   5.0
# Name: 0.25, dtype: float64
# Q3:  HeartDiseaseorAttack     0.0
# HighBP                   1.0
# HighChol                 1.0
# CholCheck                1.0
# BMI                     31.0
# Smoker                   1.0
# Stroke                   0.0
# Diabetes                 0.0
# PhysActivity             1.0
# HvyAlcoholConsump        0.0
# MentHlth                 2.0
# PhysHlth                 3.0
# Sex                      1.0
# Age                     10.0
# Education                6.0
# ...

# %%
data2_clean
# Out:
#         HeartDiseaseorAttack  HighBP  HighChol  CholCheck   BMI  Smoker  \
# 3                          0       1         0          1  27.0       0
# 4                          0       1         1          1  24.0       0
# 5                          0       1         1          1  25.0       1
# 7                          0       1         1          1  25.0       1
# 15                         0       1         0          1  33.0       0
# ...                      ...     ...       ...        ...   ...     ...
# 129984                     0       0         0          1  24.0       0
# 129987                     0       0         1          1  31.0       0
# 129988                     0       0         0          1  25.0       1
# 129992                     0       1         0          1  27.0       0
# 129995                     0       0         0          1  29.0       0
#
#         Stroke  Diabetes  PhysActivity  HvyAlcoholConsump  MentHlth  PhysHlth  \
# ...

# %%
data_category_0 = data2[data2['HeartDiseaseorAttack'] == 0].copy()
data_category_1 = data2[data2['HeartDiseaseorAttack'] == 1].copy()

Q1_0 = data_category_0.quantile(0.25)
Q3_0 = data_category_0.quantile(0.75)
IQR_0 = Q3_0 - Q1_0

lower_bound_0 = Q1_0 - 1.5 * IQR_0
upper_bound_0 = Q3_0 + 1.5 * IQR_0
mask_0 = (data_category_0 >= lower_bound_0) & (data_category_0 <= upper_bound_0)
data_category_0_cleaned = data_category_0[mask_0.all(axis=1)].copy()
data_final_filtered = pd.concat([data_category_0_cleaned, data_category_1])

print(f"Original data2 shape: {data2.shape}")
print(f"Shape of category 0 before cleaning: {data_category_0.shape}")
print(f"Shape of category 0 after cleaning: {data_category_0_cleaned.shape}")
print(f"Shape of category 1 (untouched): {data_category_1.shape}")
print(f"Final combined data shape: {data_final_filtered.shape}")

display(data_final_filtered.head())
# Out:
# Original data2 shape: (129998, 16)
# Shape of category 0 before cleaning: (117842, 16)
# Shape of category 0 after cleaning: (56576, 16)
# Shape of category 1 (untouched): (12156, 16)
# Final combined data shape: (68732, 16)
#     HeartDiseaseorAttack  HighBP  HighChol  CholCheck   BMI  Smoker  Stroke  \
# 3                      0       1         0          1  27.0       0       0
# 4                      0       1         1          1  24.0       0       0
# 5                      0       1         1          1  25.0       1       0
# 7                      0       1         1          1  25.0       1       0
# 15                     0       1         0          1  33.0       0       0
#
#     Diabetes  PhysActivity  HvyAlcoholConsump  MentHlth  PhysHlth  Sex  Age  \
# 3          0             1                  0         0         0    0   11
# 4          0             1                  0         3         0    0   11
# ...

# %%
final_df = data_final_filtered
display(final_df.head())
# Out:
#     HeartDiseaseorAttack  HighBP  HighChol  CholCheck   BMI  Smoker  Stroke  \
# 3                      0       1         0          1  27.0       0       0
# 4                      0       1         1          1  24.0       0       0
# 5                      0       1         1          1  25.0       1       0
# 7                      0       1         1          1  25.0       1       0
# 15                     0       1         0          1  33.0       0       0
#
#     Diabetes  PhysActivity  HvyAlcoholConsump  MentHlth  PhysHlth  Sex  Age  \
# 3          0             1                  0         0         0    0   11
# 4          0             1                  0         3         0    0   11
# 5          0             1                  0         0         2    1   10
# 7          0             1                  0         0         0    0   11
# 15         0             1                  0         5         0    0    6
#
#     Education  Income
# 3           3       6
# ...

# %%
data3 = pd.read_csv("/content/Salary_dataset.csv")
data3
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
data3.shape
# Out:
# (30, 3)

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
x = data3['YearsExperience']
y = data3['Salary']
x_train , x_test , y_train , y_test = train_test_split(x,y,train_size=0.8 , test_size = 0.2 , random_state = 12)
print(x_train.shape)
print(x_test.shape)
# Out:
# (24,)
# (6,)

# %%
accuracy1 = r2_score(y_test, y_pred)
print(f"R-squared score: {accuracy1}")
# Out:
# R-squared score: 0.9429269163491423

# %%
from sklearn.preprocessing import StandardScaler , MinMaxScaler
scaler = StandardScaler()
x_train_scale = scaler.fit_transform(x_train.values.reshape(-1, 1))
x_test_scale = scaler.transform(x_test.values.reshape(-1, 1))
print(x_train_scale.shape)
print(x_test_scale.shape)
# Out:
# (24, 1)
# (6, 1)

# %%
from sklearn.metrics import r2_score

# %%
accuracy = r2_score(y_test, y_pred)
print(f"R-squared score: {accuracy}")
# Out:
# R-squared score: 0.9429269163491423

# %%
MinMax = MinMaxScaler()
MinMax
